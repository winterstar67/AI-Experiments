# %%
import sys, platform, subprocess, datetime
import torch

print("===== Environment Info =====")
print("OS:", platform.platform())
print("Python:", sys.version)
print("PyTorch:", torch.__version__)
print("CUDA (torch built with):", torch.version.cuda)
print("cuDNN version:", torch.backends.cudnn.version())

print("GPU available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
    print("GPU compute capability:", torch.cuda.get_device_capability(0))
    print("GPU total memory (GB):", torch.cuda.get_device_properties(0).total_memory / 1e9)

try:
    import transformers
    print("transformers:", transformers.__version__)
except ImportError:
    print("transformers: not installed")

print("\n--- nvidia-smi (driver version included")
print(subprocess.run(["nvidia-smi"], capture_output=True, text=True).stdout)
# Out:
# ===== Environment Info =====
# OS: Linux-6.6.122+-x86_64-with-glibc2.35
# Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# PyTorch: 2.11.0+cu128
# CUDA (torch built with): 12.8
# cuDNN version: 91900
# GPU available: True
# GPU name: Tesla T4
# GPU compute capability: (7, 5)
# GPU total memory (GB): 15.637086208
# transformers: 5.15.0
#
# --- nvidia-smi (driver version included
# Thu Aug 20 13:15:28 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8             12W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# %cd "/content/drive/MyDrive/Project/nanoGPT/Memory measurement/One SelfAttention layer/"
# Out:
# /content/drive/MyDrive/Project/nanoGPT/Memory measurement/One SelfAttention layer

# %%
# !python SelfAttention_Memory.py --batch_size=12 --compile=False
# Out:
# Overriding: batch_size = 12
# Overriding: compile = False
# tokens per iteration will be: 491,520
# Initializing a new model from scratch
# defaulting to vocab_size of GPT-2 to 50304 (50257 rounded up for efficiency)
# using slow attention.
# number of parameters: 123.59M
# num decayed parameter tensors: 50, with 124,354,560 parameters
# num non-decayed parameter tensors: 25, with 19,200 parameters
# using fused AdamW: True
# memory_allocated right after reset: 0.5139875411987305 GB
# max_memory_allocated right after reset: 0.5139875411987305 GB
# [GPU MEM - before loss computation] allocated=0.51GB  reserved=0.54GB  (peak allocated=0.51GB, peak reserved=0.54GB)
# [GPU MEM - Only block 0 attention layer] allocated=0.67GB  reserved=1.96GB  (peak allocated=1.86GB, peak reserved=1.96GB)
# [GPU MEM - after loss computation] allocated=0.52GB  reserved=8.87GB  (peak allocated=7.50GB, peak reserved=8.87GB)
# val loss 10.9945
# time for one computation 00:00:29
