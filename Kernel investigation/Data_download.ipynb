# %% [markdown]
# # HellaSwag Download

# %%
SAVE_DIR = "./drive/MyDrive/Project/nanoGPT/Kernel investigation/data/hellaswag"

# %%
import requests
from tqdm import tqdm

def download_file(url, fname, chunk_size=1024):
    resp = requests.get(url, stream=True)
    total = int(resp.headers.get("content-length", 0))
    with open(fname, "wb") as file, tqdm(total=total, unit="iB", unit_scale=True) as bar:
        for data in resp.iter_content(chunk_size=chunk_size):
            size = file.write(data)
            bar.update(size)

download_file(
    "https://raw.githubusercontent.com/rowanz/hellaswag/master/data/hellaswag_val.jsonl",
    f"{SAVE_DIR}/hellaswag_val.jsonl"
)

download_file(
    "https://raw.githubusercontent.com/rowanz/hellaswag/master/data/hellaswag_val.jsonl",
    f"{SAVE_DIR}/hellaswag_test.jsonl"
)
# Out:
# 12.2MiB [00:00, 52.4MiB/s]

# %%
import pandas as pd
SAVE_DIR = "./drive/MyDrive/Project/nanoGPT/Kernel investigation/data/hellaswag"
# Construct the full path to the downloaded file
val_file_path = f"{SAVE_DIR}/hellaswag_val.jsonl"

# Load the .jsonl file into a pandas DataFrame
# The 'lines=True' argument is crucial for .jsonl files
df_val = pd.read_json(val_file_path, lines=True)

# Display the first 5 rows of the DataFrame to verify loading
display(df_val.head())
# Out:
#    ind        activity_label  \
# 0   24  Roof shingle removal
# 1   92        Clean and jerk
# 2  106              Canoeing
# 3  114             High jump
# 4  116             High jump
#
#                                                ctx_a  \
# 0                        A man is sitting on a roof.
# 1  A lady walks to a barbell. She bends down and ...
# 2  Two women in a child are shown in a canoe whil...
# 3                     A boy is running down a track.
# 4  The boy lifts his body above the height of a p...
#
#                            ctx_b  \
# 0                             he
# 1                       the lady
# 2  the child and a different man
# 3                        the boy
# 4                        the boy
#
#                                                  ctx split split_type  label  \
# 0                     A man is sitting on a roof. he   val   indomain      3
# 1  A lady walks to a barbell. She bends down and ...   val   zeroshot      3
# 2  Two women in a child are shown in a canoe whil...   val   indomain      2
# 3             A boy is running down a track. the boy   val   zeroshot      2
# 4  The boy lifts his body above the height of a p...   val   zeroshot      1
#
#                                              endings  \
# 0  [is using wrap to wrap a pair of skis., is rip...
# 1  [swings and lands in her arms., pulls the barb...
# 2  [are then shown paddling down a river in a boa...
# 3  [runs into a car., gets in a mat., lifts his b...
# 4  [turns his body around on the mat., gets up fr...
#
#                    source_id
# 0  activitynet~v_-JhWjGDPHMY
# 1  activitynet~v_-lJS58hyo1c
# 2  activitynet~v_-xQvJmC2jhk
# 3  activitynet~v_-zHX3Gdx6I4
# 4  activitynet~v_-zHX3Gdx6I4

# %% [markdown]
# # Fineweb10B_val_000000.bin download

# %%
# !pip install -q huggingface_hub

import os
from huggingface_hub import hf_hub_download

SAVE_DIR = "/content/drive/MyDrive/Project/nanoGPT/Kernel investigation/data/fineweb10B"
os.makedirs(SAVE_DIR, exist_ok=True)

hf_hub_download(
    repo_id="kjj0/fineweb10B-gpt2",
    filename="fineweb_val_000000.bin",
    repo_type="dataset",
    local_dir=SAVE_DIR,
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# fineweb_val_000000.bin: reconstructing file:   0%|          |  0.00B /  200MB
# fineweb_val_000000.bin: downloading bytes:           |  0.00B
# '/content/drive/MyDrive/Project/nanoGPT/2026-08-04 GPT Evaluation/data/fineweb10B/fineweb_val_000000.bin'
