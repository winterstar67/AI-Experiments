# %%
import sys, platform, subprocess, datetime
import torch

print("===== Environment Info =====")
print("OS:", platform.platform())
print("Python:", sys.version)
print("PyTorch:", torch.__version__)
print("CUDA (torch built with):", torch.version.cuda)
print("cuDNN version:", torch.backends.cudnn.version())

print("GPU available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
    print("GPU compute capability:", torch.cuda.get_device_capability(0))
    print("GPU total memory (GB):", torch.cuda.get_device_properties(0).total_memory / 1e9)

try:
    import transformers
    print("transformers:", transformers.__version__)
except ImportError:
    print("transformers: not installed")

print("\n--- nvidia-smi (driver version included")
print(subprocess.run(["nvidia-smi"], capture_output=True, text=True).stdout)
# Out:
# ===== Environment Info =====
# OS: Linux-6.6.122+-x86_64-with-glibc2.35
# Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# PyTorch: 2.11.0+cu128
# CUDA (torch built with): 12.8
# cuDNN version: 91900
# GPU available: True
# GPU name: Tesla T4
# GPU compute capability: (7, 5)
# GPU total memory (GB): 15.637086208
# transformers: 5.13.1
#
# --- nvidia-smi (driver version included
# Tue Aug 18 01:55:23 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8             11W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# %cd "/content/drive/MyDrive/Project/nanoGPT/KV Cache/3_time_estimation_of_one_SelfAttention_Layer/"

# %%
# !python one_selfattention_layer_estimation.py
# Out:
# loading weights from pretrained gpt: gpt2
# forcing vocab_size=50257, block_size=1024, bias=True
# overriding dropout rate to 0.0
# WARNING: using slow attention.
# number of parameters: 123.65M
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 665/665 [00:00<00:00, 4.00MB/s]
#
# model.safetensors: downloading bytes:  23% 124M/548M [00:01<00:02, 175MB/s, 9.71MB/s  ]
# model.safetensors: downloading bytes:  58% 317M/548M [00:01<00:00, 318MB/s, 26.3MB/s  ]
# model.safetensors: downloading bytes:  70% 385M/548M [00:02<00:00, 268MB/s, 32.5MB/s  ]
# model.safetensors: downloading bytes:  84% 458M/548M [00:02<00:00, 207MB/s, 39.6MB/s  ]
# model.safetensors: reconstructing file:  73% 402M/548M [00:02<00:00, 217MB/s, 24.8MB/s  ]
# model.safetensors: downloading bytes: 100% 474M/474M [00:03<00:00, 156MB/s, 41.7MB/s  ]
# model.safetensors: reconstructing file: 100% 548M/548M [00:03<00:00, 180MB/s, 48.8MB/s  ]
# Loading weights: 100% 148/148 [00:00<00:00, 6038.96it/s]
# generation_config.json: 100% 124/124 [00:00<00:00, 577kB/s]
# ===== running_mode = inf_no_cache =====
# /usr/local/lib/python3.12/dist-packages/torch/profiler/profiler.py:224: UserWarning: Warning: Profiler clears events at the end of each cycle.Only events from the current cycle will be reported.To keep events across cycles, set acc_events=True.
#   _warn_once(
# [inf_no_cache] step 1014: next tokens = ['\n', 'ide', ' the', ',', ',', ' I', ' your', '?', ' much', ',', '\n', '\n', ' me', ' the', 'US', "'"]
# [inf_no_cache] step 1015: next tokens = ['p', ',', ' right', ' and', ' and', ' will', ' cause', '\n', ' as', ' and', '\n', '\n', ',', ' way', ':', 'er']
# [inf_no_cache] step 1016: next tokens = ['urs', ' and', ',', ' the', ' the', '\n', '.', '\n', ' I', ' the', 'your', 'I', '\n', '\n', '\n', '-']
# [inf_no_cache] step 1017: next tokens = ['ue', ',', '\n', ' time', ' spears', '\n', '\n', 'COM', ' can', ' gods', ' own', ' will', '\n', '\n', '\n', 'press']
# [inf_no_cache] step 1018: next tokens = [' us', ' as', '\n', '\n', ',', 'give', '\n', 'IN', ',', ',', ',', ' make', 'I', 'He', 'I', ' you']
# [inf_no_cache] step 1019: next tokens = [',', ' you', 'I', '\n', '\n', ' him', 'L', 'I', ' and', ' and', ' and', ' my', ' have', ' will', ' will', ',']
# [inf_no_cache] step 1020: next tokens = [' and', ' are', ' would', 'Will', '\n', ' to', 'ART', 'US', ' I', ' the', ' your', ' house', ' no', ',', ' not', '\n']
# [inf_no_cache] step 1021: next tokens = [' the', ',', ' have', ' be', 'And', ' you', 'I', ':', ' am', ' gods', ' own', ' reel', ' more', ' in', ' be', '\n']
# [inf_no_cache] step 1022: next tokens = [' state', '\n', ' been', ' short', ' the', ',', 'US', '\n', ' not', ',', ' is', ' tonight', ' to', ' the', ' so', 'I']
# ========== 1) Basic table ==========
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                            aten::linear         0.05%     801.519us         0.39%       6.815ms      92.097us       0.000us         0.00%        1.546s      20.895ms            74
# void magma_sgemmEx_kernel<float, __nv_bfloat16, __nv...         0.00%       0.000us         0.00%       0.000us       0.000us     977.595ms        58.21%     977.595ms      19.951ms            49
#                                             aten::addmm         0.11%       1.937ms         0.14%       2.398ms      49.965us     975.787ms        58.10%     975.787ms      20.329ms            48
#                                            aten::matmul         0.03%     500.441us         0.27%       4.782ms     129.249us       0.000us         0.00%     434.384ms      11.740ms            37
#                                               aten::bmm         0.04%     767.408us         0.05%     950.348us      39.598us     244.819ms        14.58%     244.819ms      10.201ms            24
# void magma_sgemmEx_kernel<float, __nv_bfloat16, __nv...         0.00%       0.000us         0.00%       0.000us       0.000us     244.819ms        14.58%     244.819ms      10.201ms            24
#                                             aten::copy_         0.07%       1.197ms        90.62%        1.580s      11.792ms     209.076ms        12.45%     209.076ms       1.560ms           134
#                                           aten::softmax         0.01%     110.465us         8.51%     148.455ms      12.371ms       0.000us         0.00%     182.178ms      15.181ms            12
#                                                aten::to         0.01%      92.068us        90.59%        1.580s      31.593ms       0.000us         0.00%     138.054ms       2.761ms            50
#                                          aten::_to_copy         0.02%     334.939us        90.59%        1.580s      31.591ms       0.000us         0.00%     138.054ms       2.761ms            50
#                                          aten::_softmax         0.01%     240.732us         8.47%     147.621ms      12.302ms     110.872ms         6.60%     110.872ms       9.239ms            12
# void (anonymous namespace)::softmax_warp_forward<flo...         0.00%       0.000us         0.00%       0.000us       0.000us     110.872ms         6.60%     110.872ms       9.239ms            12
#                                       aten::masked_fill         0.01%     138.269us         0.05%     900.455us      75.038us       0.000us         0.00%     102.068ms       8.506ms            12
# void at::native::unrolled_elementwise_kernel<at::nat...         0.00%       0.000us         0.00%       0.000us       0.000us      71.306ms         4.25%      71.306ms       5.942ms            12
# void at::native::vectorized_elementwise_kernel<4, at...         0.00%       0.000us         0.00%       0.000us       0.000us      66.747ms         3.97%      66.747ms       1.804ms            37
#                                      aten::masked_fill_         0.01%     135.051us         0.01%     252.336us      21.028us      60.997ms         3.63%      60.997ms       5.083ms            12
# void at::native::elementwise_kernel<128, 4, at::nati...         0.00%       0.000us         0.00%       0.000us       0.000us      60.997ms         3.63%      60.997ms       5.083ms            12
#                                             aten::clone         0.01%     245.938us         0.10%       1.824ms      30.401us       0.000us         0.00%      60.989ms       1.016ms            60
#                          Memcpy DtoD (Device -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us      41.071ms         2.45%      41.071ms       3.423ms            12
#                                               aten::mul         0.01%     192.669us         0.02%     285.438us      23.787us      40.872ms         2.43%      40.872ms       3.406ms            12
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 1.744s
# Self CUDA time total: 1.679s
#
# ========== 2) Table groupd by shape ==========
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------------------------------------------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls                                            Input Shapes
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------------------------------------------------
# void magma_sgemmEx_kernel<float, __nv_bfloat16, __nv...         0.00%       0.000us         0.00%       0.000us       0.000us     977.595ms        58.21%     977.595ms      19.951ms            49                                                      []
#                                            aten::linear         0.01%     212.744us         0.13%       2.260ms      94.159us       0.000us         0.00%     624.122ms      26.005ms            24                  [[16, 1023, 768], [3072, 768], [3072]]
#                                            aten::linear         0.01%     198.536us         0.14%       2.443ms     101.776us       0.000us         0.00%     502.107ms      20.921ms            24                  [[16, 1023, 768], [2304, 768], [2304]]
#                                            aten::linear         0.01%     197.876us         0.05%     878.669us      73.222us       0.000us         0.00%     340.871ms      28.406ms            12                  [[16, 1023, 3072], [768, 3072], [768]]
#                                             aten::addmm         0.02%     412.122us         0.03%     527.641us      43.970us     340.871ms        20.30%     340.871ms      28.406ms            12             [[768], [16368, 3072], [3072, 768], [], []]
#                                             aten::addmm         0.03%     479.246us         0.03%     582.596us      48.550us     310.200ms        18.47%     310.200ms      25.850ms            12             [[3072], [16368, 768], [768, 3072], [], []]
#                                            aten::matmul         0.01%     228.402us         0.17%       2.934ms     122.262us       0.000us         0.00%     283.686ms      11.820ms            24              [[16, 12, 1023, 1023], [16, 12, 1023, 64]]
#                                             aten::addmm         0.03%     579.840us         0.04%     686.312us      57.193us     249.204ms        14.84%     249.204ms      20.767ms            12             [[2304], [16368, 768], [768, 2304], [], []]
# void magma_sgemmEx_kernel<float, __nv_bfloat16, __nv...         0.00%       0.000us         0.00%       0.000us       0.000us     244.819ms        14.58%     244.819ms      10.201ms            24                                                      []
#                                           aten::softmax         0.01%     110.465us         8.51%     148.455ms      12.371ms       0.000us         0.00%     182.178ms      15.181ms            12                          [[16, 12, 1023, 1023], [], []]
#                                             aten::copy_         0.02%     267.930us         0.04%     707.021us      19.639us     171.700ms        10.22%     171.700ms       4.769ms            36        [[16, 12, 1023, 1023], [16, 12, 1023, 1023], []]
#                                            aten::matmul         0.01%     259.189us         0.10%       1.739ms     144.924us       0.000us         0.00%     148.891ms      12.408ms            12                [[16, 12, 1023, 64], [16, 12, 64, 1023]]
#                                               aten::bmm         0.02%     389.990us         0.03%     481.813us      40.151us     136.610ms         8.13%     136.610ms      11.384ms            12                      [[192, 1023, 64], [192, 64, 1023]]
#                                          aten::_to_copy         0.01%     154.401us         0.06%       1.077ms      44.890us       0.000us         0.00%     130.629ms       5.443ms            24          [[16, 12, 1023, 1023], [], [], [], [], [], []]
#                                          aten::_softmax         0.01%     240.732us         8.47%     147.621ms      12.302ms     110.872ms         6.60%     110.872ms       9.239ms            12                          [[16, 12, 1023, 1023], [], []]
# void (anonymous namespace)::softmax_warp_forward<flo...         0.00%       0.000us         0.00%       0.000us       0.000us     110.872ms         6.60%     110.872ms       9.239ms            12                                                      []
#                                               aten::bmm         0.02%     377.418us         0.03%     468.535us      39.045us     108.209ms         6.44%     108.209ms       9.017ms            12                    [[192, 1023, 1023], [192, 1023, 64]]
#                                       aten::masked_fill         0.01%     138.269us         0.05%     900.455us      75.038us       0.000us         0.00%     102.068ms       8.506ms            12          [[16, 12, 1023, 1023], [1, 1, 1023, 1023], []]
#                                            aten::linear         0.01%     159.507us         0.05%     885.337us      73.778us       0.000us         0.00%      75.513ms       6.293ms            12                    [[16, 1023, 768], [768, 768], [768]]
#                                             aten::addmm         0.03%     465.663us         0.03%     601.792us      50.149us      75.513ms         4.50%      75.513ms       6.293ms            12               [[768], [16368, 768], [768, 768], [], []]
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------------------------------------------------
# Self CPU time total: 1.744s
# Self CUDA time total: 1.679s
#
# [inf_no_cache] step 1023: next tokens = [' will', '\n', ' a', ':', ' spears', ' and', ':', '\n', ' ashamed', ' and', ' too', ':', ' do', ' end', ' bold', ' do']
# ===== running_mode = inf_cache =====
# [inf_cache] step 1014: next tokens = ['\n', 'ide', ' the', ',', ',', ' I', ' your', '?', ' much', ',', '\n', '\n', ' me', ' the', 'US', "'"]
# [inf_cache] step 1015: next tokens = ['p', ',', ' right', ' and', ' and', ' will', ' cause', '\n', ' as', ' I', '\n', '\n', ',', ' way', ':', 'er']
# [inf_cache] step 1016: next tokens = ['raise', ' and', ',', ' the', ' the', '\n', '.', '\n', ' I', ' know', 'your', 'I', '\n', '\n', '\n', '-']
# [inf_cache] step 1017: next tokens = [' us', ',', '\n', ' time', ' spears', '\n', '\n', 'COM', ' can', ' not', ' own', ' will', '\n', '\n', '\n', 'press']
# [inf_cache] step 1018: next tokens = [',', ' if', '\n', '\n', ',', 'give', '\n', 'IN', ',', ',', '.', ' make', 'I', 'He', 'I', ' you']
# [inf_cache] step 1019: next tokens = [' and', ' thou', 'And', '\n', ' and', ' him', 'L', 'I', ' and', ' but', '\n', ' my', ' have', ' will', ' have', ',']
# [inf_cache] step 1020: next tokens = [' the', ' w', ' half', 'Is', ' the', ' to', 'ART', 'US', ' I', ' I', '\n', ' house', ' no', ',', ' not', '\n']
# [inf_cache] step 1021: next tokens = [' state', 'ilt', ' to', ' not', '\n', ' you', 'I', ':', ' am', ' am', 'BR', ' reel', ' more', ' if', ' the', '\n']
# [inf_cache] step 1022: next tokens = [' will', ',', ' the', ' yet', '\n', ',', 'US', '\n', ' a', '\n', 'UT', ' tonight', ' to', ' he', ' least', 'I']
# ========== 1) Basic table ==========
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                            aten::matmul         1.08%     534.715us        13.23%       6.545ms     133.577us       0.000us         0.00%      56.949ms       1.162ms            49
#                                            aten::linear         1.46%     722.032us        11.82%       5.851ms      79.064us       0.000us         0.00%      29.180ms     394.322us            74
#                                             aten::copy_         2.41%       1.193ms        68.13%      33.715ms     230.925us      29.160ms        53.10%      29.160ms     199.725us           146
#                                             aten::clone         0.35%     172.328us         2.55%       1.262ms      26.295us       0.000us         0.00%      19.132ms     398.574us            48
#                                           aten::reshape         0.48%     236.228us         2.45%       1.214ms      23.797us       0.000us         0.00%      19.066ms     373.847us            51
# void at::native::elementwise_kernel<128, 4, at::nati...         0.00%       0.000us         0.00%       0.000us       0.000us      19.066ms        34.72%      19.066ms     529.616us            36
#                                             aten::addmm         3.18%       1.573ms         4.10%       2.030ms      42.299us      18.509ms        33.70%      18.509ms     385.610us            48
# void magma_sgemmEx_kernel<float, __nv_bfloat16, __nv...         0.00%       0.000us         0.00%       0.000us       0.000us      16.181ms        29.46%      16.181ms       1.245ms            13
#                                                aten::to         0.23%     116.208us        67.68%      33.495ms     452.639us       0.000us         0.00%       9.792ms     132.321us            74
#                                          aten::_to_copy         0.84%     416.227us        67.45%      33.379ms     451.068us       0.000us         0.00%       9.792ms     132.321us            74
# void at::native::elementwise_kernel<128, 4, at::nati...         0.00%       0.000us         0.00%       0.000us       0.000us       9.450ms        17.21%       9.450ms     393.738us            24
# void gemmSN_TN_kernel<float, 128, 16, 2, 4, 8, 9, fa...         0.00%       0.000us         0.00%       0.000us       0.000us       5.325ms         9.70%       5.325ms     147.910us            36
#                                               aten::bmm         1.40%     690.453us         1.74%     863.071us      35.961us       3.135ms         5.71%       3.135ms     130.606us            24
#                                                aten::mm         0.09%      44.750us         0.12%      59.526us      59.526us       2.997ms         5.46%       2.997ms       2.997ms             1
# std::enable_if<true, void>::type internal::gemvx::ke...         0.00%       0.000us         0.00%       0.000us       0.000us       1.627ms         2.96%       1.627ms     135.604us            12
# std::enable_if<true, void>::type internal::gemvx::ke...         0.00%       0.000us         0.00%       0.000us       0.000us       1.507ms         2.74%       1.507ms     125.609us            12
#                                           aten::softmax         0.18%      89.796us         1.26%     621.751us      51.813us       0.000us         0.00%     399.131us      33.261us            12
#                                        aten::layer_norm         0.33%     165.272us         2.51%       1.241ms      49.647us       0.000us         0.00%     264.604us      10.584us            25
#                                 aten::native_layer_norm         0.97%     480.462us         2.17%       1.076ms      43.036us     264.604us         0.48%     264.604us      10.584us            25
# void at::native::(anonymous namespace)::vectorized_l...         0.00%       0.000us         0.00%       0.000us       0.000us     264.604us         0.48%     264.604us      10.584us            25
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 49.490ms
# Self CUDA time total: 54.920ms
#
# ========== 2) Table groupd by shape ==========
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ---------------------------------------------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls                                         Input Shapes
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ---------------------------------------------------
#                                            aten::matmul         0.52%     255.421us         6.83%       3.379ms     140.782us       0.000us         0.00%      35.528ms       1.480ms            24                [[16, 12, 1, 64], [16, 12, 64, 1023]]
# void at::native::elementwise_kernel<128, 4, at::nati...         0.00%       0.000us         0.00%       0.000us       0.000us      19.066ms        34.72%      19.066ms     529.616us            36                                                   []
#                                             aten::copy_         0.35%     174.181us         0.73%     359.680us      14.987us      18.519ms        33.72%      18.519ms     771.608us            24         [[16, 12, 64, 1023], [16, 12, 64, 1023], []]
#                                            aten::matmul         0.54%     267.391us         6.24%       3.086ms     128.596us       0.000us         0.00%      18.424ms     767.684us            24              [[16, 12, 1, 1023], [16, 12, 1023, 64]]
# void magma_sgemmEx_kernel<float, __nv_bfloat16, __nv...         0.00%       0.000us         0.00%       0.000us       0.000us      16.181ms        29.46%      16.181ms       1.245ms            13                                                   []
#                                           aten::reshape         0.08%      42.019us         0.64%     314.341us      26.195us       0.000us         0.00%      13.812ms       1.151ms            12                             [[16, 12, 64, 1023], []]
#                                             aten::clone         0.08%      38.492us         0.52%     258.818us      21.568us       0.000us         0.00%      13.812ms       1.151ms            12                             [[16, 12, 64, 1023], []]
#                                            aten::linear         0.27%     133.138us         1.43%     708.027us      59.002us       0.000us         0.00%      13.185ms       1.099ms            12                  [[16, 1, 3072], [768, 3072], [768]]
#                                             aten::addmm         0.68%     334.603us         0.89%     439.532us      36.628us      13.185ms        24.01%      13.185ms       1.099ms            12             [[768], [16, 3072], [3072, 768], [], []]
#                                             aten::copy_         0.37%     182.456us         0.77%     380.739us      15.864us       9.906ms        18.04%       9.906ms     412.743us            24         [[16, 12, 1023, 64], [16, 12, 1023, 64], []]
# void at::native::elementwise_kernel<128, 4, at::nati...         0.00%       0.000us         0.00%       0.000us       0.000us       9.450ms        17.21%       9.450ms     393.738us            24                                                   []
#                                            aten::linear         0.03%      14.771us         0.54%     267.746us     133.873us       0.000us         0.00%       5.997ms       2.998ms             2                     [[16, 1, 768], [50257, 768], []]
# void gemmSN_TN_kernel<float, 128, 16, 2, 4, 8, 9, fa...         0.00%       0.000us         0.00%       0.000us       0.000us       5.325ms         9.70%       5.325ms     147.910us            36                                                   []
#                                            aten::linear         0.43%     215.110us         3.94%       1.951ms      81.274us       0.000us         0.00%       5.270ms     219.603us            24                  [[16, 1, 768], [3072, 768], [3072]]
#                                           aten::reshape         0.17%      85.610us         0.85%     418.256us      34.855us       0.000us         0.00%       5.163ms     430.216us            12                             [[16, 12, 1023, 64], []]
#                                             aten::clone         0.09%      44.864us         0.63%     313.148us      26.096us       0.000us         0.00%       5.163ms     430.216us            12                             [[16, 12, 1023, 64], []]
#                                                aten::to         0.03%      16.504us         0.75%     372.447us      31.037us       0.000us         0.00%       4.743ms     395.270us            12                 [[16, 12, 1023, 64], [], [], [], []]
#                                          aten::_to_copy         0.14%      68.821us         0.72%     355.943us      29.662us       0.000us         0.00%       4.743ms     395.270us            12         [[16, 12, 1023, 64], [], [], [], [], [], []]
#                                                aten::to         0.04%      18.457us         0.82%     408.243us      34.020us       0.000us         0.00%       4.706ms     392.206us            12                 [[16, 12, 64, 1023], [], [], [], []]
#                                          aten::_to_copy         0.15%      71.921us         0.79%     389.786us      32.482us       0.000us         0.00%       4.706ms     392.206us            12         [[16, 12, 64, 1023], [], [], [], [], [], []]
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ---------------------------------------------------
# Self CPU time total: 49.490ms
# Self CUDA time total: 54.920ms
#
# [inf_cache] step 1023: next tokens = [' be', ' and', ' left', ' come', 'c', ' and', ':', '\n', ' man', '\n', 'US', ':', ' do', ' be', ' doubt', ' do']
