# %%
import sys, platform, subprocess
import torch

print("===== Environment Info =====")
print("OS:", platform.platform())
print("Python:", sys.version)
print("PyTorch:", torch.__version__)
print("CUDA (torch built with):", torch.version.cuda)
print("cuDNN version:", torch.backends.cudnn.version())

print("GPU available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
    print("GPU compute capability:", torch.cuda.get_device_capability(0))
    print("GPU total memory (GB):", torch.cuda.get_device_properties(0).total_memory / 1e9)

try:
    import transformers
    print("transformers:", transformers.__version__)
except ImportError:
    print("transformers: not installed")

result = subprocess.run(
    ["nvidia-smi"],
    capture_output=True,
    text=True
).stdout

lines = result.splitlines()

# remove the date/time on the first line
if lines:
    lines = lines[1:]

print("\n".join(lines))
# Out:
# ===== Environment Info =====
# OS: Linux-6.6.122+-x86_64-with-glibc2.39
# Python: 3.13.15 (main, Aug  6 2026, 11:06:22) [GCC 13.3.0]
# PyTorch: 2.11.0+cu128
# CUDA (torch built with): 12.8
# cuDNN version: 91900
# GPU available: True
# GPU name: Tesla T4
# GPU compute capability: (7, 5)
# GPU total memory (GB): 15.637086208
# transformers: 5.16.1
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# ...

# %%
# %cd "/content/drive/MyDrive/Project/nanoGPT/Quantization/GPTQ/1_Quantization/"
# Out:
# /content/drive/MyDrive/Project/nanoGPT/Quantization/GPTQ/1_Quantization

# %%
# !python GPTQ_Quantization.py --dtype=float32 --quant_dtype=int8 --batch_size=1
# Out:
# loading weights from pretrained gpt: gpt2
# forcing vocab_size=50257, block_size=1024, bias=True
# overriding dropout rate to 0.0
# number of parameters: 123.65M
# ...
# config.json: 100% 665/665 [00:00<00:00, 2.45MB/s]
#
# model.safetensors: downloading bytes:  38% 207M/548M [00:01<00:01, 285MB/s, 16.3MB/s  ]
# model.safetensors: reconstructing file:  12% 67.1M/548M [00:01<00:09, 51.2MB/s]
# model.safetensors: downloading bytes:  45% 248M/548M [00:01<00:01, 246MB/s, 22.1MB/s  ]
# model.safetensors: downloading bytes:  64% 350M/548M [00:01<00:00, 256MB/s, 28.1MB/s  ]
# model.safetensors: downloading bytes:  81% 445M/548M [00:02<00:00, 289MB/s, 36.6MB/s  ]
# model.safetensors: reconstructing file:  73% 402M/548M [00:02<00:00, 214MB/s, 31.0MB/s  ]
# model.safetensors: downloading bytes: 100% 474M/474M [00:02<00:00, 179MB/s, 42.1MB/s  ]
# model.safetensors: reconstructing file: 100% 548M/548M [00:02<00:00, 207MB/s, 49.0MB/s  ]
# Loading weights: 100% 148/148 [00:00<00:00, 4812.82it/s]
# ...

# %%
# !python GPTQ_Quantization.py --dtype=float32 --quant_dtype=int8 --batch_size=2
# Out:
# loading weights from pretrained gpt: gpt2
# forcing vocab_size=50257, block_size=1024, bias=True
# overriding dropout rate to 0.0
# number of parameters: 123.65M
# Loading weights: 100% 148/148 [00:00<00:00, 4285.84it/s]
# Dtype: torch.float32
# Quant Dtype: torch.int8
# Batch Size: 2
# 0th handle 100% Done - Total elapsed: 19.3s (Forward: 18.8s, Quant: 0.4s), Tokens: 10480640, Time/token: 0.0018 ms, ETA: 924.3s
# 1th handle 100% Done - Total elapsed: 61.7s (Forward: 61.4s, Quant: 0.3s), Tokens: 10480640, Time/token: 0.0059 ms, ETA: 2898.9s
# Exception ignored in audit hook:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.13/dist-packages/filelock/_api.py", line 1785, in _audit_fork_safety
#     def _audit_fork_safety(  # pragma: no cover - CPython disables tracing while Python audit hooks run
# KeyboardInterrupt:
# Traceback (most recent call last):
# ...

# %%
# !python GPTQ_Quantization.py --dtype=float32 --quant_dtype=int8 --batch_size=4
# Out:
# loading weights from pretrained gpt: gpt2
# forcing vocab_size=50257, block_size=1024, bias=True
# overriding dropout rate to 0.0
# number of parameters: 123.65M
# ...
# Loading weights: 100% 148/148 [00:00<00:00, 4099.08it/s]
# Dtype: torch.float32
# Quant Dtype: torch.int8
# Batch Size: 4
# 0th handle 100% Done - Total elapsed: 20.1s (Forward: 19.7s, Quant: 0.4s), Tokens: 10482688, Time/token: 0.0019 ms, ETA: 963.9s
# 1th handle 100% Done - Total elapsed: 61.5s (Forward: 61.3s, Quant: 0.2s), Tokens: 10482688, Time/token: 0.0059 ms, ETA: 2889.0s
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Project/nanoGPT/Quantization/GPTQ/1_Quantization/GPTQ_Quantization.py", line 163, in <module>
#     x, y = samples[:-1].view(_B, -1).to(device), samples[1:].view(_B, -1).to(device)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
# KeyboardInterrupt

# %%
# !python GPTQ_Quantization.py --dtype=float32 --quant_dtype=int8 --batch_size=16
# Out:
# loading weights from pretrained gpt: gpt2
# forcing vocab_size=50257, block_size=1024, bias=True
# overriding dropout rate to 0.0
# number of parameters: 123.65M
# ...
# Loading weights: 100% 148/148 [00:00<00:00, 4384.47it/s]
# Dtype: torch.float32
# Quant Dtype: torch.int8
# Batch Size: 16
# 0th handle 100% Done - Total elapsed: 16.7s (Forward: 16.3s, Quant: 0.4s), Tokens: 10484736, Time/token: 0.0016 ms, ETA: 801.7s
# 1th handle 100% Done - Total elapsed: 61.0s (Forward: 60.7s, Quant: 0.2s), Tokens: 10484736, Time/token: 0.0058 ms, ETA: 2864.8s
# 2th handle 100% Done - Total elapsed: 77.6s (Forward: 77.4s, Quant: 0.2s), Tokens: 10484736, Time/token: 0.0074 ms, ETA: 3571.3s
# 3th handle 100% Done - Total elapsed: 145.4s (Forward: 144.5s, Quant: 0.9s), Tokens: 10484736, Time/token: 0.0139 ms, ETA: 6542.6s
# 4th handle 100% Done - Total elapsed: 110.1s (Forward: 109.9s, Quant: 0.2s), Tokens: 10484736, Time/token: 0.0105 ms, ETA: 4842.9s
# Traceback (most recent call last):
# ...

# %%
# !python GPTQ_Quantization.py --dtype=float32 --quant_dtype=int8 --batch_size=32
# Out:
# loading weights from pretrained gpt: gpt2
# forcing vocab_size=50257, block_size=1024, bias=True
# overriding dropout rate to 0.0
# number of parameters: 123.65M
# ...
# Loading weights: 100% 148/148 [00:00<00:00, 3986.16it/s]
# Dtype: torch.float32
# Quant Dtype: torch.int8
# Batch Size: 32
# 0th handle 100% Done - Total elapsed: 17.6s (Forward: 17.1s, Quant: 0.6s), Tokens: 10484736, Time/token: 0.0017 ms, ETA: 845.1s
# 1th handle 100% Done - Total elapsed: 60.4s (Forward: 60.1s, Quant: 0.2s), Tokens: 10484736, Time/token: 0.0058 ms, ETA: 2836.6s
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Project/nanoGPT/Quantization/GPTQ/1_Quantization/GPTQ_Quantization.py", line 163, in <module>
#     x, y = samples[:-1].view(_B, -1).to(device), samples[1:].view(_B, -1).to(device)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
# KeyboardInterrupt

# %%
# !python GPTQ_Quantization.py --dtype=float32 --quant_dtype=int8 --batch_size=64
# Out:
# loading weights from pretrained gpt: gpt2
# forcing vocab_size=50257, block_size=1024, bias=True
# overriding dropout rate to 0.0
# number of parameters: 123.65M
# ...
# Loading weights: 100% 148/148 [00:00<00:00, 16709.92it/s]
# Dtype: torch.float32
# Quant Dtype: torch.int8
# Batch Size: 64
# 0th handle 100% Done - Total elapsed: 17.3s (Forward: 16.9s, Quant: 0.4s), Tokens: 10484736, Time/token: 0.0017 ms, ETA: 831.9s
# 1th handle 100% Done - Total elapsed: 61.8s (Forward: 61.6s, Quant: 0.2s), Tokens: 10484736, Time/token: 0.0059 ms, ETA: 2905.5s
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Project/nanoGPT/Quantization/GPTQ/1_Quantization/GPTQ_Quantization.py", line 163, in <module>
#     x, y = samples[:-1].view(_B, -1).to(device), samples[1:].view(_B, -1).to(device)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
# KeyboardInterrupt

# %%
# !python GPTQ_Quantization.py --dtype=float32 --quant_dtype=int8 --batch_size=120
# Out:
# loading weights from pretrained gpt: gpt2
# forcing vocab_size=50257, block_size=1024, bias=True
# overriding dropout rate to 0.0
# number of parameters: 123.65M
# ...
# Loading weights: 100% 148/148 [00:00<00:00, 4608.85it/s]
# Dtype: torch.float32
# Quant Dtype: torch.int8
# Batch Size: 120
# 0th handle 100% Done - Total elapsed: 17.3s, Tokens: 10484736, Time/token: 0.0016 ms, ETA: 830.3s
# 1th handle 100% Done - Total elapsed: 66.1s, Tokens: 10484736, Time/token: 0.0063 ms, ETA: 3105.4s
# 2th handle 100% Done - Total elapsed: 84.6s, Tokens: 10484736, Time/token: 0.0081 ms, ETA: 3893.8s
# 3th handle 100% Done - Total elapsed: 150.6s, Tokens: 10484736, Time/token: 0.0144 ms, ETA: 6775.5s
# 4th handle 100% Done - Total elapsed: 114.6s, Tokens: 10484736, Time/token: 0.0109 ms, ETA: 5043.0s
# 5th handle 100% Done - Total elapsed: 160.5s, Tokens: 10484736, Time/token: 0.0153 ms, ETA: 6902.4s
# Traceback (most recent call last):
# ...
